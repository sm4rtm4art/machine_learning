# %% [markdown]
# # Project Report: Template
#
# This notebook visualizes results from the template project.
#
# **Note**: This notebook should only contain visualization code. All logic should be in `project/` modules.

# %%
# Parameters (for papermill)
run_id = None  # Set to MLflow run ID

# %%
import json
from pathlib import Path

from ml_portfolio.common.paths import get_project_paths

# Setup paths
PROJECT_NAME = "_template"
paths = get_project_paths(PROJECT_NAME)

if run_id:
    report_dir = paths.reports_dir / run_id
    print(f"Loading results from: {report_dir}")
else:
    print("No run_id provided. Set run_id parameter to load results.")
    report_dir = None
